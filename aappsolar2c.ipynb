# %%
# Import necessary libraries
import os
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
import seaborn as sns
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization, Activation, Add, Input, Concatenate, GlobalAveragePooling2D, AveragePooling2D, DepthwiseConv2D, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Load data
X_train = np.load('/kaggle/input/kalki-solar/2c/2c/X_train_n2c.npy')
y_train = np.load('/kaggle/input/kalki-solar/2c/2c/y_train_n2c.npy')
X_val = np.load('/kaggle/input/kalki-solar/2c/2c/X_val_n2c.npy')
y_val = np.load('/kaggle/input/kalki-solar/2c/2c/y_val_n2c.npy')
X_test = np.load('/kaggle/input/kalki-solar/2c/2c/X_test_n2c.npy')
y_test = np.load('/kaggle/input/kalki-solar/2c/2c/y_test_n2c.npy')


# Check the shape of target labels
print(f"Shape of y_train: {y_train.shape}")

# Squeeze-and-Excitation (SE) Block
def se_block(input_tensor, ratio=8):
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    return Multiply()([input_tensor, se])

# Enhanced Pyramid Block with Depthwise Separable Convolution and SE Block
def enhanced_pyramid_block(x, filters):
    # Depthwise Separable Conv Layer
    x = DepthwiseConv2D((3, 3), padding='same', depth_multiplier=1, activation='relu')(x)
    x = Conv2D(filters, (1, 1), activation='relu')(x)
    x = BatchNormalization()(x)
    
    # Second Conv Layer with SE Block
    x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
    x = se_block(x)
    x = BatchNormalization()(x)
    
    # Max Pooling Layer
    x = MaxPooling2D(pool_size=(2, 2))(x)
    return x

# Adaptive Attention Pyramid Network (AAPN)
def adaptive_attention_pyramid_net(input_shape=(40, 24, 1), num_classes=2):
    input_tensor = Input(shape=input_shape)
    
    # Initial Conv Layer
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
    x = BatchNormalization()(x)
    
    # First Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=64)
    
    # Second Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=128)
    
    # Third Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=256)
    
    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    
    # Fully connected layer with 128 units
    x = Dense(128, activation='relu')(x)
    
    # Increased Dropout layer for better regularization
    x = Dropout(0.4)(x)
    
    # Output layer (Class probabilities)
    output_tensor = Dense(num_classes, activation='softmax')(x)
    
    # Build and compile the model
    model = Model(inputs=input_tensor, outputs=output_tensor)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# Define the model
input_shape = (40, 24, 1)
num_classes = 2
model = adaptive_attention_pyramid_net(input_shape=input_shape, num_classes=num_classes)

# Model summary
model.summary()

# Define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val),
                    shuffle=True, callbacks=[lr_scheduler])

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Evaluate model performance on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix", fontsize=16)
plt.ylabel("True Class", fontsize=14)
plt.xlabel("Predicted Class", fontsize=14)
plt.show()

# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve for Each Class", fontsize=16)
plt.legend(loc="lower right")
plt.show()

# Plot training history (accuracy and loss graphs)
def plot_training_history(history):
    # Retrieve accuracy and loss values from training history
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    # Plot training & validation accuracy values
    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy', color='#2E8B57', linewidth=2)  # Green
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='#1E90FF', linewidth=2)  # Blue
    plt.title('Training and Validation Accuracy', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Accuracy', fontweight='bold', fontsize=14)
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the accuracy plot to the output folder
    acc_plot_path = os.path.join('/kaggle/working/', 'accuracy_plot.png')
    plt.savefig(acc_plot_path, dpi=300)
    plt.show()

    # Plot training & validation loss values
    plt.figure()
    plt.plot(epochs, loss, label='Training Loss', color='#FF6347', linewidth=2)  # Tomato red
    plt.plot(epochs, val_loss, label='Validation Loss', color='#8A2BE2', linewidth=2)  # BlueViolet
    plt.title('Training and Validation Loss', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Loss', fontweight='bold', fontsize=14)
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the loss plot to the output folder
    loss_plot_path = os.path.join('/kaggle/working/', 'loss_plot.png')
    plt.savefig(loss_plot_path, dpi=300)
    plt.show()

# Plot training history
plot_training_history(history)
# Out:
# Shape of y_train: (64000, 2)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 24, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 40, 24,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 40, 24,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 40, 24,    │        320 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 24,    │      2,112 │ depthwise_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 40, 24,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 40, 24,    │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ multiply[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 20, 12,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 20, 12,    │        640 │ max_pooling2d[0]… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 12,    │      8,320 │ depthwise_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 12,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_4[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      2,176 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 20, 12,    │          0 │ conv2d_4[0][0],   │
# │ (Multiply)          │ 128)              │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ multiply_1[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 10, 6,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 10, 6,     │      1,280 │ max_pooling2d_1[… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 10, 6,     │     33,024 │ depthwise_conv2d… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 10, 6,     │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_6[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 10, 6,     │          0 │ conv2d_6[0][0],   │
# │ (Multiply)          │ 256)              │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ multiply_2[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 5, 3, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 2)         │        258 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 879,482 (3.35 MB)
#  Trainable params: 877,626 (3.35 MB)
#  Non-trainable params: 1,856 (7.25 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730285479.188833      94 service.cc:145] XLA service 0x7b1780002d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730285479.188890      94 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   19/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.5391 - loss: 1.2507
# I0000 00:00:1730285487.830923      94 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 33s 9ms/step - accuracy: 0.7736 - loss: 0.5498 - val_accuracy: 0.8475 - val_loss: 0.4348 - learning_rate: 0.0010
# Epoch 2/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8741 - loss: 0.4040 - val_accuracy: 0.8637 - val_loss: 0.3998 - learning_rate: 0.0010
# Epoch 3/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8943 - loss: 0.3757 - val_accuracy: 0.8550 - val_loss: 0.4292 - learning_rate: 0.0010
# Epoch 4/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9082 - loss: 0.3540 - val_accuracy: 0.9010 - val_loss: 0.3600 - learning_rate: 0.0010
# Epoch 5/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9218 - loss: 0.3325 - val_accuracy: 0.9075 - val_loss: 0.3494 - learning_rate: 0.0010
# Epoch 6/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9318 - loss: 0.3170 - val_accuracy: 0.9196 - val_loss: 0.3369 - learning_rate: 0.0010
# Epoch 7/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9429 - loss: 0.3028 - val_accuracy: 0.8890 - val_loss: 0.3754 - learning_rate: 0.0010
# Epoch 8/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9482 - loss: 0.2930 - val_accuracy: 0.9321 - val_loss: 0.3132 - learning_rate: 0.0010
# Epoch 9/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9550 - loss: 0.2823 - val_accuracy: 0.9210 - val_loss: 0.3263 - learning_rate: 0.0010
# Epoch 10/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9595 - loss: 0.2732 - val_accuracy: 0.9256 - val_loss: 0.3185 - learning_rate: 0.0010
# Epoch 11/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9652 - loss: 0.2637 - val_accuracy: 0.9290 - val_loss: 0.3191 - learning_rate: 0.0010
# Epoch 12/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9691 - loss: 0.2582 - val_accuracy: 0.9154 - val_loss: 0.3401 - learning_rate: 0.0010
# Epoch 13/50
# 1998/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9719 - loss: 0.2531
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9719 - loss: 0.2531 - val_accuracy: 0.9304 - val_loss: 0.3219 - learning_rate: 0.0010
# Epoch 14/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9830 - loss: 0.2348 - val_accuracy: 0.9496 - val_loss: 0.2891 - learning_rate: 5.0000e-04
# Epoch 15/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9897 - loss: 0.2232 - val_accuracy: 0.9529 - val_loss: 0.2883 - learning_rate: 5.0000e-04
# Epoch 16/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9910 - loss: 0.2208 - val_accuracy: 0.9452 - val_loss: 0.3013 - learning_rate: 5.0000e-04
# Epoch 17/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9919 - loss: 0.2188 - val_accuracy: 0.9477 - val_loss: 0.3032 - learning_rate: 5.0000e-04
# Epoch 18/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9927 - loss: 0.2168 - val_accuracy: 0.9529 - val_loss: 0.2937 - learning_rate: 5.0000e-04
# Epoch 19/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9936 - loss: 0.2145 - val_accuracy: 0.9473 - val_loss: 0.3020 - learning_rate: 5.0000e-04
# Epoch 20/50
# 1997/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9940 - loss: 0.2141
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9940 - loss: 0.2141 - val_accuracy: 0.9510 - val_loss: 0.2925 - learning_rate: 5.0000e-04
# Epoch 21/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 21s 8ms/step - accuracy: 0.9967 - loss: 0.2098 - val_accuracy: 0.9590 - val_loss: 0.2769 - learning_rate: 2.5000e-04
# Epoch 22/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9980 - loss: 0.2064 - val_accuracy: 0.9606 - val_loss: 0.2761 - learning_rate: 2.5000e-04
# Epoch 23/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9977 - loss: 0.2065 - val_accuracy: 0.9583 - val_loss: 0.2806 - learning_rate: 2.5000e-04
# Epoch 24/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9980 - loss: 0.2061 - val_accuracy: 0.9540 - val_loss: 0.2931 - learning_rate: 2.5000e-04
# Epoch 25/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9982 - loss: 0.2057 - val_accuracy: 0.9563 - val_loss: 0.2858 - learning_rate: 2.5000e-04
# Epoch 26/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9986 - loss: 0.2051 - val_accuracy: 0.9594 - val_loss: 0.2813 - learning_rate: 2.5000e-04
# Epoch 27/50
# 1995/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9988 - loss: 0.2047
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9988 - loss: 0.2047 - val_accuracy: 0.9594 - val_loss: 0.2809 - learning_rate: 2.5000e-04
# Epoch 28/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9988 - loss: 0.2045 - val_accuracy: 0.9594 - val_loss: 0.2840 - learning_rate: 1.2500e-04
# Epoch 29/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9993 - loss: 0.2032 - val_accuracy: 0.9588 - val_loss: 0.2828 - learning_rate: 1.2500e-04
# Epoch 30/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.2029 - val_accuracy: 0.9585 - val_loss: 0.2794 - learning_rate: 1.2500e-04
# Epoch 31/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9993 - loss: 0.2030 - val_accuracy: 0.9600 - val_loss: 0.2819 - learning_rate: 1.2500e-04
# Epoch 32/50
# 1995/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9994 - loss: 0.2029
# Epoch 32: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9994 - loss: 0.2029 - val_accuracy: 0.9590 - val_loss: 0.2824 - learning_rate: 1.2500e-04
# Epoch 33/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.2023 - val_accuracy: 0.9600 - val_loss: 0.2816 - learning_rate: 6.2500e-05
# Epoch 34/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2021 - val_accuracy: 0.9596 - val_loss: 0.2825 - learning_rate: 6.2500e-05
# Epoch 35/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.2021 - val_accuracy: 0.9588 - val_loss: 0.2824 - learning_rate: 6.2500e-05
# Epoch 36/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.2023 - val_accuracy: 0.9588 - val_loss: 0.2828 - learning_rate: 6.2500e-05
# Epoch 37/50
# 1994/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.2020
# Epoch 37: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.2020 - val_accuracy: 0.9602 - val_loss: 0.2825 - learning_rate: 6.2500e-05
# Epoch 38/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2018 - val_accuracy: 0.9613 - val_loss: 0.2828 - learning_rate: 3.1250e-05
# Epoch 39/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.2021 - val_accuracy: 0.9604 - val_loss: 0.2805 - learning_rate: 3.1250e-05
# Epoch 40/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2018 - val_accuracy: 0.9596 - val_loss: 0.2840 - learning_rate: 3.1250e-05
# Epoch 41/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2017 - val_accuracy: 0.9613 - val_loss: 0.2829 - learning_rate: 3.1250e-05
# Epoch 42/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9999 - loss: 0.2017
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2017 - val_accuracy: 0.9619 - val_loss: 0.2817 - learning_rate: 3.1250e-05
# Epoch 43/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2016 - val_accuracy: 0.9598 - val_loss: 0.2817 - learning_rate: 1.5625e-05
# Epoch 44/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2017 - val_accuracy: 0.9594 - val_loss: 0.2818 - learning_rate: 1.5625e-05
# Epoch 45/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2017 - val_accuracy: 0.9592 - val_loss: 0.2830 - learning_rate: 1.5625e-05
# Epoch 46/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 1.0000 - loss: 0.2016 - val_accuracy: 0.9583 - val_loss: 0.2822 - learning_rate: 1.5625e-05
# Epoch 47/50
# 1999/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9999 - loss: 0.2017
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2017 - val_accuracy: 0.9598 - val_loss: 0.2826 - learning_rate: 1.5625e-05
# Epoch 48/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 1.0000 - loss: 0.2015 - val_accuracy: 0.9596 - val_loss: 0.2829 - learning_rate: 1.0000e-05
# Epoch 49/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.2016 - val_accuracy: 0.9600 - val_loss: 0.2819 - learning_rate: 1.0000e-05
# Epoch 50/50
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 1.0000 - loss: 0.2016 - val_accuracy: 0.9608 - val_loss: 0.2820 - learning_rate: 1.0000e-05
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9645 - loss: 0.2724
# Test Loss: 0.2752179503440857
# Test Accuracy: 0.9633928537368774
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      5574
#            1       0.96      0.97      0.96      5626
#
#     accuracy                           0.96     11200
#    macro avg       0.96      0.96      0.96     11200
# weighted avg       0.96      0.96      0.96     11200

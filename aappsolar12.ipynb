# %%
# Import necessary libraries
import os
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
import seaborn as sns
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization, Activation, Add, Input, Concatenate, GlobalAveragePooling2D, AveragePooling2D, DepthwiseConv2D, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Load data
X_train = np.load('/kaggle/input/kalki-solar12/archana/X_train_n12c.npy')
y_train = np.load('/kaggle/input/kalki-solar12/archana/y_train_n12c.npy')
X_val = np.load('/kaggle/input/kalki-solar12/archana/X_val_n12c.npy')
y_val = np.load('/kaggle/input/kalki-solar12/archana/y_val_n12c.npy')
X_test = np.load('/kaggle/input/kalki-solar12/archana/X_test_n12c.npy')
y_test = np.load('/kaggle/input/kalki-solar12/archana/y_test_n12c.npy')

# Check the shape of target labels
print(f"Shape of y_train: {y_train.shape}")

# Squeeze-and-Excitation (SE) Block
def se_block(input_tensor, ratio=8):
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    return Multiply()([input_tensor, se])

# Enhanced Pyramid Block with Depthwise Separable Convolution and SE Block
def enhanced_pyramid_block(x, filters):
    # Depthwise Separable Conv Layer
    x = DepthwiseConv2D((3, 3), padding='same', depth_multiplier=1, activation='relu')(x)
    x = Conv2D(filters, (1, 1), activation='relu')(x)
    x = BatchNormalization()(x)
    
    # Second Conv Layer with SE Block
    x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
    x = se_block(x)
    x = BatchNormalization()(x)
    
    # Max Pooling Layer
    x = MaxPooling2D(pool_size=(2, 2))(x)
    return x

# Adaptive Attention Pyramid Network (AAPN)
def adaptive_attention_pyramid_net(input_shape=(40, 24, 1), num_classes=12):
    input_tensor = Input(shape=input_shape)
    
    # Initial Conv Layer
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
    x = BatchNormalization()(x)
    
    # First Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=64)
    
    # Second Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=128)
    
    # Third Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=256)
    
    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    
    # Fully connected layer with 128 units
    x = Dense(128, activation='relu')(x)
    
    # Increased Dropout layer for better regularization
    x = Dropout(0.4)(x)
    
    # Output layer (Class probabilities)
    output_tensor = Dense(num_classes, activation='softmax')(x)
    
    # Build and compile the model
    model = Model(inputs=input_tensor, outputs=output_tensor)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# Define the model
input_shape = (40, 24, 1)
num_classes = 12
model = adaptive_attention_pyramid_net(input_shape=input_shape, num_classes=num_classes)

# Model summary
model.summary()

# Define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)

# Train the model
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_data=(X_val, y_val),
                    shuffle=True, callbacks=[lr_scheduler])

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Evaluate model performance on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.ylabel("True Class")
plt.xlabel("Predicted Class")
plt.show()

# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Each Class")
plt.legend(loc="lower right")
plt.show()

# Plot training history (accuracy and loss graphs)
def plot_training_history(history):
    # Retrieve accuracy and loss values from training history
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    # Plot training & validation accuracy values
    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy', color='#2E8B57', linewidth=2)  # Green
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='#1E90FF', linewidth=2)  # Blue
    plt.title('Training and Validation Accuracy', fontweight='bold')
    plt.xlabel('Epochs', fontweight='bold')
    plt.ylabel('Accuracy', fontweight='bold')
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the accuracy plot to the output folder
    acc_plot_path = os.path.join('/kaggle/working/', 'accuracy_plot.png')
    plt.savefig(acc_plot_path, dpi=300)
    plt.show()

    # Plot training & validation loss values
    plt.figure()
    plt.plot(epochs, loss, label='Training Loss', color='#FF6347', linewidth=2)  # Tomato red
    plt.plot(epochs, val_loss, label='Validation Loss', color='#8A2BE2', linewidth=2)  # BlueViolet
    plt.title('Training and Validation Loss', fontweight='bold')
    plt.xlabel('Epochs', fontweight='bold')
    plt.ylabel('Loss', fontweight='bold')
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the loss plot to the output folder
    loss_plot_path = os.path.join('/kaggle/working/', 'loss_plot.png')
    plt.savefig(loss_plot_path, dpi=300)
    plt.show()

# Plot training history
plot_training_history(history)
# Out:
# Shape of y_train: (64000, 12)
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 40, 24, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 40, 24,    │        320 │ input_layer_2[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        128 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_6  │ (None, 40, 24,    │        320 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 40, 24,    │      2,112 │ depthwise_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 40, 24,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_16[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_16 (Dense)    │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_17 (Dense)    │ (None, 64)        │        576 │ dense_16[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 40, 24,    │          0 │ conv2d_16[0][0],  │
# │ (Multiply)          │ 64)               │            │ dense_17[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ multiply_6[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_6     │ (None, 20, 12,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_7  │ (None, 20, 12,    │        640 │ max_pooling2d_6[… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 20, 12,    │      8,320 │ depthwise_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 20, 12,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_18[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 128)       │      2,176 │ dense_18[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 20, 12,    │          0 │ conv2d_18[0][0],  │
# │ (Multiply)          │ 128)              │            │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ multiply_7[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_7     │ (None, 10, 6,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_8  │ (None, 10, 6,     │      1,280 │ max_pooling2d_7[… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 10, 6,     │     33,024 │ depthwise_conv2d… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 10, 6,     │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_20[0][0]   │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 256)       │      8,448 │ dense_20[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 10, 6,     │          0 │ conv2d_20[0][0],  │
# │ (Multiply)          │ 256)              │            │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ multiply_8[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_8     │ (None, 5, 3, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_8[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_22 (Dense)    │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 128)       │          0 │ dense_22[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_23 (Dense)    │ (None, 12)        │      1,548 │ dropout_2[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 880,772 (3.36 MB)
#  Trainable params: 878,916 (3.35 MB)
#  Non-trainable params: 1,856 (7.25 KB)
# Epoch 1/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 30s 9ms/step - accuracy: 0.6169 - loss: 1.5511 - val_accuracy: 0.6812 - val_loss: 1.3009 - learning_rate: 0.0010
# Epoch 2/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.7380 - loss: 1.1997 - val_accuracy: 0.7423 - val_loss: 1.1728 - learning_rate: 0.0010
# Epoch 3/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.7758 - loss: 1.1006 - val_accuracy: 0.7594 - val_loss: 1.1185 - learning_rate: 0.0010
# Epoch 4/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8043 - loss: 1.0227 - val_accuracy: 0.7925 - val_loss: 1.0355 - learning_rate: 0.0010
# Epoch 5/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8271 - loss: 0.9692 - val_accuracy: 0.7675 - val_loss: 1.0820 - learning_rate: 0.0010
# Epoch 6/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8522 - loss: 0.9130 - val_accuracy: 0.7806 - val_loss: 1.0709 - learning_rate: 0.0010
# Epoch 7/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8651 - loss: 0.8775 - val_accuracy: 0.7865 - val_loss: 1.0449 - learning_rate: 0.0010
# Epoch 8/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.8873 - loss: 0.8319 - val_accuracy: 0.7552 - val_loss: 1.1433 - learning_rate: 0.0010
# Epoch 9/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9025 - loss: 0.7983 - val_accuracy: 0.8633 - val_loss: 0.8764 - learning_rate: 0.0010
# Epoch 10/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9192 - loss: 0.7597 - val_accuracy: 0.8404 - val_loss: 0.9321 - learning_rate: 0.0010
# Epoch 11/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9283 - loss: 0.7399 - val_accuracy: 0.6496 - val_loss: 1.5151 - learning_rate: 0.0010
# Epoch 12/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9390 - loss: 0.7146 - val_accuracy: 0.8248 - val_loss: 0.9881 - learning_rate: 0.0010
# Epoch 13/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9494 - loss: 0.6909 - val_accuracy: 0.8121 - val_loss: 1.0287 - learning_rate: 0.0010
# Epoch 14/150
# 1994/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9555 - loss: 0.6758
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9555 - loss: 0.6759 - val_accuracy: 0.4829 - val_loss: 2.0052 - learning_rate: 0.0010
# Epoch 15/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9740 - loss: 0.6327 - val_accuracy: 0.8969 - val_loss: 0.8098 - learning_rate: 5.0000e-04
# Epoch 16/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9863 - loss: 0.6034 - val_accuracy: 0.8835 - val_loss: 0.8430 - learning_rate: 5.0000e-04
# Epoch 17/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9892 - loss: 0.5954 - val_accuracy: 0.9031 - val_loss: 0.7998 - learning_rate: 5.0000e-04
# Epoch 18/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9916 - loss: 0.5888 - val_accuracy: 0.9008 - val_loss: 0.8063 - learning_rate: 5.0000e-04
# Epoch 19/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9919 - loss: 0.5855 - val_accuracy: 0.9000 - val_loss: 0.8032 - learning_rate: 5.0000e-04
# Epoch 20/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9938 - loss: 0.5809 - val_accuracy: 0.9035 - val_loss: 0.8026 - learning_rate: 5.0000e-04
# Epoch 21/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9944 - loss: 0.5778 - val_accuracy: 0.8438 - val_loss: 0.9403 - learning_rate: 5.0000e-04
# Epoch 22/150
# 1994/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9942 - loss: 0.5767
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9942 - loss: 0.5767 - val_accuracy: 0.8783 - val_loss: 0.8693 - learning_rate: 5.0000e-04
# Epoch 23/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9968 - loss: 0.5682 - val_accuracy: 0.9071 - val_loss: 0.7833 - learning_rate: 2.5000e-04
# Epoch 24/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9982 - loss: 0.5613 - val_accuracy: 0.9098 - val_loss: 0.7723 - learning_rate: 2.5000e-04
# Epoch 25/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9983 - loss: 0.5597 - val_accuracy: 0.9104 - val_loss: 0.7766 - learning_rate: 2.5000e-04
# Epoch 26/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9985 - loss: 0.5583 - val_accuracy: 0.9075 - val_loss: 0.7800 - learning_rate: 2.5000e-04
# Epoch 27/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9989 - loss: 0.5568 - val_accuracy: 0.9092 - val_loss: 0.7745 - learning_rate: 2.5000e-04
# Epoch 28/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9990 - loss: 0.5561 - val_accuracy: 0.9077 - val_loss: 0.7797 - learning_rate: 2.5000e-04
# Epoch 29/150
# 1994/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.5571
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9985 - loss: 0.5571 - val_accuracy: 0.9065 - val_loss: 0.7756 - learning_rate: 2.5000e-04
# Epoch 30/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9994 - loss: 0.5533 - val_accuracy: 0.9121 - val_loss: 0.7704 - learning_rate: 1.2500e-04
# Epoch 31/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9993 - loss: 0.5522 - val_accuracy: 0.9144 - val_loss: 0.7678 - learning_rate: 1.2500e-04
# Epoch 32/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5510 - val_accuracy: 0.9121 - val_loss: 0.7654 - learning_rate: 1.2500e-04
# Epoch 33/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9994 - loss: 0.5504 - val_accuracy: 0.9133 - val_loss: 0.7639 - learning_rate: 1.2500e-04
# Epoch 34/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5500 - val_accuracy: 0.9119 - val_loss: 0.7696 - learning_rate: 1.2500e-04
# Epoch 35/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5497 - val_accuracy: 0.9102 - val_loss: 0.7699 - learning_rate: 1.2500e-04
# Epoch 36/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5495 - val_accuracy: 0.9123 - val_loss: 0.7659 - learning_rate: 1.2500e-04
# Epoch 37/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5492 - val_accuracy: 0.9146 - val_loss: 0.7652 - learning_rate: 1.2500e-04
# Epoch 38/150
# 1997/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9997 - loss: 0.5488
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5488 - val_accuracy: 0.9129 - val_loss: 0.7650 - learning_rate: 1.2500e-04
# Epoch 39/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5489 - val_accuracy: 0.9123 - val_loss: 0.7651 - learning_rate: 6.2500e-05
# Epoch 40/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5480 - val_accuracy: 0.9127 - val_loss: 0.7608 - learning_rate: 6.2500e-05
# Epoch 41/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5475 - val_accuracy: 0.9137 - val_loss: 0.7632 - learning_rate: 6.2500e-05
# Epoch 42/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5473 - val_accuracy: 0.9110 - val_loss: 0.7653 - learning_rate: 6.2500e-05
# Epoch 43/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5473 - val_accuracy: 0.9117 - val_loss: 0.7631 - learning_rate: 6.2500e-05
# Epoch 44/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5470 - val_accuracy: 0.9129 - val_loss: 0.7629 - learning_rate: 6.2500e-05
# Epoch 45/150
# 1995/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.5465
# Epoch 45: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5465 - val_accuracy: 0.9133 - val_loss: 0.7637 - learning_rate: 6.2500e-05
# Epoch 46/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9995 - loss: 0.5470 - val_accuracy: 0.9119 - val_loss: 0.7604 - learning_rate: 3.1250e-05
# Epoch 47/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5465 - val_accuracy: 0.9137 - val_loss: 0.7607 - learning_rate: 3.1250e-05
# Epoch 48/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5466 - val_accuracy: 0.9135 - val_loss: 0.7621 - learning_rate: 3.1250e-05
# Epoch 49/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5461 - val_accuracy: 0.9125 - val_loss: 0.7622 - learning_rate: 3.1250e-05
# Epoch 50/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5467 - val_accuracy: 0.9135 - val_loss: 0.7594 - learning_rate: 3.1250e-05
# Epoch 51/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5456 - val_accuracy: 0.9127 - val_loss: 0.7647 - learning_rate: 3.1250e-05
# Epoch 52/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5459 - val_accuracy: 0.9123 - val_loss: 0.7606 - learning_rate: 3.1250e-05
# Epoch 53/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5462 - val_accuracy: 0.9144 - val_loss: 0.7611 - learning_rate: 3.1250e-05
# Epoch 54/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5460 - val_accuracy: 0.9144 - val_loss: 0.7606 - learning_rate: 3.1250e-05
# Epoch 55/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.5458
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5458 - val_accuracy: 0.9129 - val_loss: 0.7622 - learning_rate: 3.1250e-05
# Epoch 56/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5455 - val_accuracy: 0.9125 - val_loss: 0.7618 - learning_rate: 1.5625e-05
# Epoch 57/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5455 - val_accuracy: 0.9133 - val_loss: 0.7614 - learning_rate: 1.5625e-05
# Epoch 58/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5452 - val_accuracy: 0.9140 - val_loss: 0.7635 - learning_rate: 1.5625e-05
# Epoch 59/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5452 - val_accuracy: 0.9125 - val_loss: 0.7610 - learning_rate: 1.5625e-05
# Epoch 60/150
# 1995/2000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9997 - loss: 0.5452
# Epoch 60: ReduceLROnPlateau reducing learning rate to 1e-05.
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5452 - val_accuracy: 0.9140 - val_loss: 0.7610 - learning_rate: 1.5625e-05
# Epoch 61/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5456 - val_accuracy: 0.9125 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 62/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5452 - val_accuracy: 0.9121 - val_loss: 0.7616 - learning_rate: 1.0000e-05
# Epoch 63/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5450 - val_accuracy: 0.9125 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 64/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5452 - val_accuracy: 0.9121 - val_loss: 0.7616 - learning_rate: 1.0000e-05
# Epoch 65/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5452 - val_accuracy: 0.9129 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 66/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5451 - val_accuracy: 0.9121 - val_loss: 0.7614 - learning_rate: 1.0000e-05
# Epoch 67/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5450 - val_accuracy: 0.9112 - val_loss: 0.7629 - learning_rate: 1.0000e-05
# Epoch 68/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5446 - val_accuracy: 0.9123 - val_loss: 0.7599 - learning_rate: 1.0000e-05
# Epoch 69/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5455 - val_accuracy: 0.9123 - val_loss: 0.7612 - learning_rate: 1.0000e-05
# Epoch 70/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5452 - val_accuracy: 0.9119 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 71/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5455 - val_accuracy: 0.9131 - val_loss: 0.7603 - learning_rate: 1.0000e-05
# Epoch 72/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5453 - val_accuracy: 0.9133 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 73/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5455 - val_accuracy: 0.9133 - val_loss: 0.7604 - learning_rate: 1.0000e-05
# Epoch 74/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5454 - val_accuracy: 0.9131 - val_loss: 0.7624 - learning_rate: 1.0000e-05
# Epoch 75/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5450 - val_accuracy: 0.9121 - val_loss: 0.7616 - learning_rate: 1.0000e-05
# Epoch 76/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5455 - val_accuracy: 0.9125 - val_loss: 0.7615 - learning_rate: 1.0000e-05
# Epoch 77/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5451 - val_accuracy: 0.9125 - val_loss: 0.7616 - learning_rate: 1.0000e-05
# Epoch 78/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5447 - val_accuracy: 0.9137 - val_loss: 0.7619 - learning_rate: 1.0000e-05
# Epoch 79/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5446 - val_accuracy: 0.9125 - val_loss: 0.7612 - learning_rate: 1.0000e-05
# Epoch 80/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5450 - val_accuracy: 0.9133 - val_loss: 0.7625 - learning_rate: 1.0000e-05
# Epoch 81/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5449 - val_accuracy: 0.9119 - val_loss: 0.7622 - learning_rate: 1.0000e-05
# Epoch 82/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5447 - val_accuracy: 0.9127 - val_loss: 0.7642 - learning_rate: 1.0000e-05
# Epoch 83/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5453 - val_accuracy: 0.9131 - val_loss: 0.7624 - learning_rate: 1.0000e-05
# Epoch 84/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5449 - val_accuracy: 0.9142 - val_loss: 0.7637 - learning_rate: 1.0000e-05
# Epoch 85/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5449 - val_accuracy: 0.9119 - val_loss: 0.7635 - learning_rate: 1.0000e-05
# Epoch 86/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5450 - val_accuracy: 0.9127 - val_loss: 0.7633 - learning_rate: 1.0000e-05
# Epoch 87/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5450 - val_accuracy: 0.9121 - val_loss: 0.7632 - learning_rate: 1.0000e-05
# Epoch 88/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5447 - val_accuracy: 0.9135 - val_loss: 0.7620 - learning_rate: 1.0000e-05
# Epoch 89/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5449 - val_accuracy: 0.9137 - val_loss: 0.7617 - learning_rate: 1.0000e-05
# Epoch 90/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5446 - val_accuracy: 0.9135 - val_loss: 0.7612 - learning_rate: 1.0000e-05
# Epoch 91/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.5444 - val_accuracy: 0.9131 - val_loss: 0.7613 - learning_rate: 1.0000e-05
# Epoch 92/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5447 - val_accuracy: 0.9127 - val_loss: 0.7622 - learning_rate: 1.0000e-05
# Epoch 93/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5446 - val_accuracy: 0.9119 - val_loss: 0.7623 - learning_rate: 1.0000e-05
# Epoch 94/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.5446 - val_accuracy: 0.9123 - val_loss: 0.7633 - learning_rate: 1.0000e-05
# Epoch 95/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5449 - val_accuracy: 0.9131 - val_loss: 0.7642 - learning_rate: 1.0000e-05
# Epoch 96/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5448 - val_accuracy: 0.9125 - val_loss: 0.7629 - learning_rate: 1.0000e-05
# Epoch 97/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5445 - val_accuracy: 0.9133 - val_loss: 0.7623 - learning_rate: 1.0000e-05
# Epoch 98/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5446 - val_accuracy: 0.9119 - val_loss: 0.7630 - learning_rate: 1.0000e-05
# Epoch 99/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5449 - val_accuracy: 0.9123 - val_loss: 0.7626 - learning_rate: 1.0000e-05
# Epoch 100/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5444 - val_accuracy: 0.9119 - val_loss: 0.7632 - learning_rate: 1.0000e-05
# Epoch 101/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5446 - val_accuracy: 0.9129 - val_loss: 0.7627 - learning_rate: 1.0000e-05
# Epoch 102/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5449 - val_accuracy: 0.9140 - val_loss: 0.7631 - learning_rate: 1.0000e-05
# Epoch 103/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5451 - val_accuracy: 0.9125 - val_loss: 0.7641 - learning_rate: 1.0000e-05
# Epoch 104/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5453 - val_accuracy: 0.9129 - val_loss: 0.7631 - learning_rate: 1.0000e-05
# Epoch 105/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5448 - val_accuracy: 0.9123 - val_loss: 0.7627 - learning_rate: 1.0000e-05
# Epoch 106/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5445 - val_accuracy: 0.9129 - val_loss: 0.7637 - learning_rate: 1.0000e-05
# Epoch 107/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5449 - val_accuracy: 0.9129 - val_loss: 0.7635 - learning_rate: 1.0000e-05
# Epoch 108/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5447 - val_accuracy: 0.9127 - val_loss: 0.7629 - learning_rate: 1.0000e-05
# Epoch 109/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5442 - val_accuracy: 0.9112 - val_loss: 0.7641 - learning_rate: 1.0000e-05
# Epoch 110/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5448 - val_accuracy: 0.9117 - val_loss: 0.7628 - learning_rate: 1.0000e-05
# Epoch 111/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5448 - val_accuracy: 0.9129 - val_loss: 0.7627 - learning_rate: 1.0000e-05
# Epoch 112/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5444 - val_accuracy: 0.9119 - val_loss: 0.7634 - learning_rate: 1.0000e-05
# Epoch 113/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5445 - val_accuracy: 0.9129 - val_loss: 0.7626 - learning_rate: 1.0000e-05
# Epoch 114/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5448 - val_accuracy: 0.9117 - val_loss: 0.7639 - learning_rate: 1.0000e-05
# Epoch 115/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5441 - val_accuracy: 0.9121 - val_loss: 0.7626 - learning_rate: 1.0000e-05
# Epoch 116/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5440 - val_accuracy: 0.9131 - val_loss: 0.7617 - learning_rate: 1.0000e-05
# Epoch 117/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5446 - val_accuracy: 0.9125 - val_loss: 0.7623 - learning_rate: 1.0000e-05
# Epoch 118/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5445 - val_accuracy: 0.9121 - val_loss: 0.7622 - learning_rate: 1.0000e-05
# Epoch 119/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5445 - val_accuracy: 0.9137 - val_loss: 0.7622 - learning_rate: 1.0000e-05
# Epoch 120/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.5441 - val_accuracy: 0.9135 - val_loss: 0.7631 - learning_rate: 1.0000e-05
# Epoch 121/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5443 - val_accuracy: 0.9125 - val_loss: 0.7627 - learning_rate: 1.0000e-05
# Epoch 122/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5447 - val_accuracy: 0.9125 - val_loss: 0.7623 - learning_rate: 1.0000e-05
# Epoch 123/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5441 - val_accuracy: 0.9127 - val_loss: 0.7633 - learning_rate: 1.0000e-05
# Epoch 124/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9996 - loss: 0.5446 - val_accuracy: 0.9115 - val_loss: 0.7639 - learning_rate: 1.0000e-05
# Epoch 125/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5447 - val_accuracy: 0.9119 - val_loss: 0.7631 - learning_rate: 1.0000e-05
# Epoch 126/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5442 - val_accuracy: 0.9125 - val_loss: 0.7634 - learning_rate: 1.0000e-05
# Epoch 127/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5441 - val_accuracy: 0.9119 - val_loss: 0.7628 - learning_rate: 1.0000e-05
# Epoch 128/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5444 - val_accuracy: 0.9115 - val_loss: 0.7628 - learning_rate: 1.0000e-05
# Epoch 129/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5443 - val_accuracy: 0.9117 - val_loss: 0.7634 - learning_rate: 1.0000e-05
# Epoch 130/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5445 - val_accuracy: 0.9119 - val_loss: 0.7634 - learning_rate: 1.0000e-05
# Epoch 131/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9995 - loss: 0.5445 - val_accuracy: 0.9115 - val_loss: 0.7643 - learning_rate: 1.0000e-05
# Epoch 132/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9997 - loss: 0.5446 - val_accuracy: 0.9112 - val_loss: 0.7624 - learning_rate: 1.0000e-05
# Epoch 133/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5442 - val_accuracy: 0.9110 - val_loss: 0.7628 - learning_rate: 1.0000e-05
# Epoch 134/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5444 - val_accuracy: 0.9115 - val_loss: 0.7628 - learning_rate: 1.0000e-05
# Epoch 135/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5443 - val_accuracy: 0.9117 - val_loss: 0.7644 - learning_rate: 1.0000e-05
# Epoch 136/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5440 - val_accuracy: 0.9121 - val_loss: 0.7648 - learning_rate: 1.0000e-05
# Epoch 137/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.5440 - val_accuracy: 0.9125 - val_loss: 0.7632 - learning_rate: 1.0000e-05
# Epoch 138/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9996 - loss: 0.5442 - val_accuracy: 0.9131 - val_loss: 0.7641 - learning_rate: 1.0000e-05
# Epoch 139/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5444 - val_accuracy: 0.9115 - val_loss: 0.7635 - learning_rate: 1.0000e-05
# Epoch 140/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5445 - val_accuracy: 0.9117 - val_loss: 0.7636 - learning_rate: 1.0000e-05
# Epoch 141/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5443 - val_accuracy: 0.9125 - val_loss: 0.7639 - learning_rate: 1.0000e-05
# Epoch 142/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5438 - val_accuracy: 0.9112 - val_loss: 0.7643 - learning_rate: 1.0000e-05
# Epoch 143/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5444 - val_accuracy: 0.9112 - val_loss: 0.7639 - learning_rate: 1.0000e-05
# Epoch 144/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5441 - val_accuracy: 0.9110 - val_loss: 0.7640 - learning_rate: 1.0000e-05
# Epoch 145/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9999 - loss: 0.5442 - val_accuracy: 0.9125 - val_loss: 0.7639 - learning_rate: 1.0000e-05
# Epoch 146/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5439 - val_accuracy: 0.9119 - val_loss: 0.7632 - learning_rate: 1.0000e-05
# Epoch 147/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5440 - val_accuracy: 0.9117 - val_loss: 0.7641 - learning_rate: 1.0000e-05
# Epoch 148/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9997 - loss: 0.5442 - val_accuracy: 0.9110 - val_loss: 0.7651 - learning_rate: 1.0000e-05
# Epoch 149/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 17s 8ms/step - accuracy: 0.9998 - loss: 0.5442 - val_accuracy: 0.9115 - val_loss: 0.7641 - learning_rate: 1.0000e-05
# Epoch 150/150
# 2000/2000 ━━━━━━━━━━━━━━━━━━━━ 16s 8ms/step - accuracy: 0.9998 - loss: 0.5444 - val_accuracy: 0.9110 - val_loss: 0.7658 - learning_rate: 1.0000e-05
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 350/350 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9139 - loss: 0.7670
# Test Loss: 0.7579455375671387
# Test Accuracy: 0.9151785969734192
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83      1069
#            1       0.79      0.76      0.77       702
#            2       0.88      0.88      0.88       537
#            3       0.98      0.98      0.98       869
#            4       0.99      0.92      0.95        87
#            5       0.92      0.77      0.84       134
#            6       0.89      0.83      0.86       138
#            7       0.94      0.99      0.97      5626
#            8       0.93      0.78      0.85       444
#            9       0.92      0.85      0.88       573
#           10       0.88      0.64      0.74       100
#           11       0.87      0.81      0.84       921
#
#     accuracy                           0.92     11200
#    macro avg       0.90      0.84      0.87     11200
# weighted avg       0.91      0.92      0.91     11200

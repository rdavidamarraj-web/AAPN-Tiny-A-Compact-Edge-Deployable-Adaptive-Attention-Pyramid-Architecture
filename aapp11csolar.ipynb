# %%
# Import necessary libraries
import os
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
import seaborn as sns
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization, Activation, Add, Input, Concatenate, GlobalAveragePooling2D, AveragePooling2D, DepthwiseConv2D, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Load data
X_train = np.load('/kaggle/input/kalki-solar/11c/11c/X_train_n11c.npy')
y_train = np.load('/kaggle/input/kalki-solar/11c/11c/y_train_n11c.npy')
X_val = np.load('/kaggle/input/kalki-solar/11c/11c/X_val_n11c.npy')
y_val = np.load('/kaggle/input/kalki-solar/11c/11c/y_val_n11c.npy')
X_test = np.load('/kaggle/input/kalki-solar/11c/11c/X_test_n11c.npy')
y_test = np.load('/kaggle/input/kalki-solar/11c/11c/y_test_n11c.npy')

# Check the shape of target labels
print(f"Shape of y_train: {y_train.shape}")

# Squeeze-and-Excitation (SE) Block
def se_block(input_tensor, ratio=8):
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    return Multiply()([input_tensor, se])

# Enhanced Pyramid Block with Depthwise Separable Convolution and SE Block
def enhanced_pyramid_block(x, filters):
    # Depthwise Separable Conv Layer
    x = DepthwiseConv2D((3, 3), padding='same', depth_multiplier=1, activation='relu')(x)
    x = Conv2D(filters, (1, 1), activation='relu')(x)
    x = BatchNormalization()(x)
    
    # Second Conv Layer with SE Block
    x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
    x = se_block(x)
    x = BatchNormalization()(x)
    
    # Max Pooling Layer
    x = MaxPooling2D(pool_size=(2, 2))(x)
    return x

# Adaptive Attention Pyramid Network (AAPN)
def adaptive_attention_pyramid_net(input_shape=(40, 24, 1), num_classes=11):
    input_tensor = Input(shape=input_shape)
    
    # Initial Conv Layer
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
    x = BatchNormalization()(x)
    
    # First Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=64)
    
    # Second Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=128)
    
    # Third Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=256)
    
    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    
    # Fully connected layer with 128 units
    x = Dense(128, activation='relu')(x)
    
    # Increased Dropout layer for better regularization
    x = Dropout(0.4)(x)
    
    # Output layer (Class probabilities)
    output_tensor = Dense(num_classes, activation='softmax')(x)
    
    # Build and compile the model
    model = Model(inputs=input_tensor, outputs=output_tensor)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# Define the model
input_shape = (40, 24, 1)
num_classes = 11
model = adaptive_attention_pyramid_net(input_shape=input_shape, num_classes=num_classes)

# Model summary
model.summary()

# Define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val),
                    shuffle=True, callbacks=[lr_scheduler])

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Evaluate model performance on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix", fontsize=16)
plt.ylabel("True Class", fontsize=14)
plt.xlabel("Predicted Class", fontsize=14)
plt.show()

# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve for Each Class", fontsize=16)
plt.legend(loc="lower right")
plt.show()

# Plot training history (accuracy and loss graphs)
def plot_training_history(history):
    # Retrieve accuracy and loss values from training history
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    # Plot training & validation accuracy values
    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy', color='#2E8B57', linewidth=2)  # Green
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='#1E90FF', linewidth=2)  # Blue
    plt.title('Training and Validation Accuracy', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Accuracy', fontweight='bold', fontsize=14)
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the accuracy plot to the output folder
    acc_plot_path = os.path.join('/kaggle/working/', 'accuracy_plot.png')
    plt.savefig(acc_plot_path, dpi=300)
    plt.show()

    # Plot training & validation loss values
    plt.figure()
    plt.plot(epochs, loss, label='Training Loss', color='#FF6347', linewidth=2)  # Tomato red
    plt.plot(epochs, val_loss, label='Validation Loss', color='#8A2BE2', linewidth=2)  # BlueViolet
    plt.title('Training and Validation Loss', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Loss', fontweight='bold', fontsize=14)
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the loss plot to the output folder
    loss_plot_path = os.path.join('/kaggle/working/', 'loss_plot.png')
    plt.savefig(loss_plot_path, dpi=300)
    plt.show()

# Plot training history
plot_training_history(history)
# Out:
# Shape of y_train: (32000, 11)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 24, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 40, 24,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 40, 24,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 40, 24,    │        320 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 24,    │      2,112 │ depthwise_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 40, 24,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 40, 24,    │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ multiply[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 20, 12,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 20, 12,    │        640 │ max_pooling2d[0]… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 12,    │      8,320 │ depthwise_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 12,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_4[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      2,176 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 20, 12,    │          0 │ conv2d_4[0][0],   │
# │ (Multiply)          │ 128)              │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ multiply_1[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 10, 6,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 10, 6,     │      1,280 │ max_pooling2d_1[… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 10, 6,     │     33,024 │ depthwise_conv2d… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 10, 6,     │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_6[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 10, 6,     │          0 │ conv2d_6[0][0],   │
# │ (Multiply)          │ 256)              │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ multiply_2[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 5, 3, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 11)        │      1,419 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 880,643 (3.36 MB)
#  Trainable params: 878,787 (3.35 MB)
#  Non-trainable params: 1,856 (7.25 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730280299.816763      93 service.cc:145] XLA service 0x7b4fbc00c360 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730280299.816823      93 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   19/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.1514 - loss: 2.7175
# I0000 00:00:1730280308.551614      93 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 24s 9ms/step - accuracy: 0.3918 - loss: 1.8926 - val_accuracy: 0.4883 - val_loss: 1.7189 - learning_rate: 0.0010
# Epoch 2/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6081 - loss: 1.4254 - val_accuracy: 0.5987 - val_loss: 1.4134 - learning_rate: 0.0010
# Epoch 3/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.6737 - loss: 1.2893 - val_accuracy: 0.6504 - val_loss: 1.3095 - learning_rate: 0.0010
# Epoch 4/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7111 - loss: 1.1969 - val_accuracy: 0.7038 - val_loss: 1.1907 - learning_rate: 0.0010
# Epoch 5/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7469 - loss: 1.1153 - val_accuracy: 0.7404 - val_loss: 1.1217 - learning_rate: 0.0010
# Epoch 6/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.7856 - loss: 1.0443 - val_accuracy: 0.7325 - val_loss: 1.1331 - learning_rate: 0.0010
# Epoch 7/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8213 - loss: 0.9703 - val_accuracy: 0.7421 - val_loss: 1.1204 - learning_rate: 0.0010
# Epoch 8/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.8457 - loss: 0.9113 - val_accuracy: 0.7237 - val_loss: 1.1713 - learning_rate: 0.0010
# Epoch 9/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.8814 - loss: 0.8436 - val_accuracy: 0.6700 - val_loss: 1.3249 - learning_rate: 0.0010
# Epoch 10/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9048 - loss: 0.7951 - val_accuracy: 0.7721 - val_loss: 1.0702 - learning_rate: 0.0010
# Epoch 11/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9251 - loss: 0.7550 - val_accuracy: 0.7946 - val_loss: 1.0877 - learning_rate: 0.0010
# Epoch 12/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9381 - loss: 0.7278 - val_accuracy: 0.7937 - val_loss: 1.0798 - learning_rate: 0.0010
# Epoch 13/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9509 - loss: 0.6994 - val_accuracy: 0.8208 - val_loss: 1.0051 - learning_rate: 0.0010
# Epoch 14/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9645 - loss: 0.6710 - val_accuracy: 0.7554 - val_loss: 1.1682 - learning_rate: 0.0010
# Epoch 15/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9679 - loss: 0.6581 - val_accuracy: 0.7067 - val_loss: 1.2900 - learning_rate: 0.0010
# Epoch 16/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9708 - loss: 0.6523 - val_accuracy: 0.8008 - val_loss: 1.0550 - learning_rate: 0.0010
# Epoch 17/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9771 - loss: 0.6354 - val_accuracy: 0.8158 - val_loss: 1.0172 - learning_rate: 0.0010
# Epoch 18/50
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9747 - loss: 0.6381
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 9ms/step - accuracy: 0.9747 - loss: 0.6381 - val_accuracy: 0.7833 - val_loss: 1.0811 - learning_rate: 0.0010
# Epoch 19/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9919 - loss: 0.5985 - val_accuracy: 0.8529 - val_loss: 0.9206 - learning_rate: 5.0000e-04
# Epoch 20/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9977 - loss: 0.5724 - val_accuracy: 0.8562 - val_loss: 0.9060 - learning_rate: 5.0000e-04
# Epoch 21/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9981 - loss: 0.5687 - val_accuracy: 0.8546 - val_loss: 0.9051 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9979 - loss: 0.5686 - val_accuracy: 0.8542 - val_loss: 0.9167 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9973 - loss: 0.5681 - val_accuracy: 0.8479 - val_loss: 0.9220 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9977 - loss: 0.5669 - val_accuracy: 0.8462 - val_loss: 0.9268 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9983 - loss: 0.5628 - val_accuracy: 0.8487 - val_loss: 0.9218 - learning_rate: 5.0000e-04
# Epoch 26/50
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9985 - loss: 0.5614
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9985 - loss: 0.5614 - val_accuracy: 0.8483 - val_loss: 0.9208 - learning_rate: 5.0000e-04
# Epoch 27/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9987 - loss: 0.5558 - val_accuracy: 0.8567 - val_loss: 0.8864 - learning_rate: 2.5000e-04
# Epoch 28/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.9995 - loss: 0.5515 - val_accuracy: 0.8583 - val_loss: 0.8771 - learning_rate: 2.5000e-04
# Epoch 29/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9996 - loss: 0.5497 - val_accuracy: 0.8542 - val_loss: 0.8888 - learning_rate: 2.5000e-04
# Epoch 30/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9996 - loss: 0.5492 - val_accuracy: 0.8567 - val_loss: 0.8816 - learning_rate: 2.5000e-04
# Epoch 31/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9993 - loss: 0.5487 - val_accuracy: 0.8596 - val_loss: 0.8793 - learning_rate: 2.5000e-04
# Epoch 32/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9995 - loss: 0.5487 - val_accuracy: 0.8542 - val_loss: 0.8816 - learning_rate: 2.5000e-04
# Epoch 33/50
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9993 - loss: 0.5481
# Epoch 33: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9993 - loss: 0.5481 - val_accuracy: 0.8575 - val_loss: 0.8879 - learning_rate: 2.5000e-04
# Epoch 34/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9995 - loss: 0.5460 - val_accuracy: 0.8629 - val_loss: 0.8722 - learning_rate: 1.2500e-04
# Epoch 35/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5443 - val_accuracy: 0.8583 - val_loss: 0.8760 - learning_rate: 1.2500e-04
# Epoch 36/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9994 - loss: 0.5437 - val_accuracy: 0.8608 - val_loss: 0.8763 - learning_rate: 1.2500e-04
# Epoch 37/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5435 - val_accuracy: 0.8592 - val_loss: 0.8812 - learning_rate: 1.2500e-04
# Epoch 38/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9995 - loss: 0.5428 - val_accuracy: 0.8629 - val_loss: 0.8732 - learning_rate: 1.2500e-04
# Epoch 39/50
#  996/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.5431
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9996 - loss: 0.5431 - val_accuracy: 0.8587 - val_loss: 0.8736 - learning_rate: 1.2500e-04
# Epoch 40/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9995 - loss: 0.5426 - val_accuracy: 0.8592 - val_loss: 0.8739 - learning_rate: 6.2500e-05
# Epoch 41/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5412 - val_accuracy: 0.8625 - val_loss: 0.8711 - learning_rate: 6.2500e-05
# Epoch 42/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9996 - loss: 0.5407 - val_accuracy: 0.8600 - val_loss: 0.8723 - learning_rate: 6.2500e-05
# Epoch 43/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9998 - loss: 0.5406 - val_accuracy: 0.8592 - val_loss: 0.8703 - learning_rate: 6.2500e-05
# Epoch 44/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5405 - val_accuracy: 0.8592 - val_loss: 0.8728 - learning_rate: 6.2500e-05
# Epoch 45/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9998 - loss: 0.5400 - val_accuracy: 0.8575 - val_loss: 0.8702 - learning_rate: 6.2500e-05
# Epoch 46/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5406 - val_accuracy: 0.8600 - val_loss: 0.8683 - learning_rate: 6.2500e-05
# Epoch 47/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9996 - loss: 0.5400 - val_accuracy: 0.8592 - val_loss: 0.8730 - learning_rate: 6.2500e-05
# Epoch 48/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9998 - loss: 0.5401 - val_accuracy: 0.8604 - val_loss: 0.8718 - learning_rate: 6.2500e-05
# Epoch 49/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5397 - val_accuracy: 0.8587 - val_loss: 0.8713 - learning_rate: 6.2500e-05
# Epoch 50/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 8s 8ms/step - accuracy: 0.9997 - loss: 0.5397 - val_accuracy: 0.8600 - val_loss: 0.8718 - learning_rate: 6.2500e-05
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8775 - loss: 0.8232
# Test Loss: 0.8300824165344238
# Test Accuracy: 0.8737499713897705
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1012
#            1       0.79      0.79      0.79       749
#            2       0.87      0.87      0.87       534
#            3       0.98      0.99      0.98       847
#            4       0.98      0.96      0.97       105
#            5       0.87      0.82      0.85       154
#            6       0.83      0.78      0.81       123
#            7       0.91      0.89      0.90       487
#            8       0.87      0.94      0.90       572
#            9       0.96      0.58      0.72       112
#           10       0.87      0.87      0.87       905
#
#     accuracy                           0.87      5600
#    macro avg       0.89      0.85      0.86      5600
# weighted avg       0.87      0.87      0.87      5600

# %%
# Import necessary libraries
import os
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, roc_curve, auc, confusion_matrix
import seaborn as sns
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, BatchNormalization, Activation, Add, Input, Concatenate, GlobalAveragePooling2D, AveragePooling2D, DepthwiseConv2D, Multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Load data
X_train = np.load('/kaggle/input/kalki-solar/8c/8c/X_train_n8c.npy')
y_train = np.load('/kaggle/input/kalki-solar/8c/8c/y_train_n8c.npy')
X_val = np.load('/kaggle/input/kalki-solar/8c/8c/X_val_n8c.npy')
y_val = np.load('/kaggle/input/kalki-solar/8c/8c/y_val_n8c.npy')
X_test = np.load('/kaggle/input/kalki-solar/8c/8c/X_test_n8c.npy')
y_test = np.load('/kaggle/input/kalki-solar/8c/8c/y_test_n8c.npy')

# Check the shape of target labels
print(f"Shape of y_train: {y_train.shape}")

# Squeeze-and-Excitation (SE) Block
def se_block(input_tensor, ratio=8):
    filters = input_tensor.shape[-1]
    se = GlobalAveragePooling2D()(input_tensor)
    se = Dense(filters // ratio, activation='relu')(se)
    se = Dense(filters, activation='sigmoid')(se)
    return Multiply()([input_tensor, se])

# Enhanced Pyramid Block with Depthwise Separable Convolution and SE Block
def enhanced_pyramid_block(x, filters):
    # Depthwise Separable Conv Layer
    x = DepthwiseConv2D((3, 3), padding='same', depth_multiplier=1, activation='relu')(x)
    x = Conv2D(filters, (1, 1), activation='relu')(x)
    x = BatchNormalization()(x)
    
    # Second Conv Layer with SE Block
    x = Conv2D(filters, (3, 3), padding='same', activation='relu')(x)
    x = se_block(x)
    x = BatchNormalization()(x)
    
    # Max Pooling Layer
    x = MaxPooling2D(pool_size=(2, 2))(x)
    return x

# Adaptive Attention Pyramid Network (AAPN)
def adaptive_attention_pyramid_net(input_shape=(40, 24, 1), num_classes=8):
    input_tensor = Input(shape=input_shape)
    
    # Initial Conv Layer
    x = Conv2D(32, (3, 3), padding='same', activation='relu')(input_tensor)
    x = BatchNormalization()(x)
    
    # First Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=64)
    
    # Second Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=128)
    
    # Third Adaptive Pyramid Block
    x = enhanced_pyramid_block(x, filters=256)
    
    # Global Average Pooling
    x = GlobalAveragePooling2D()(x)
    
    # Fully connected layer with 128 units
    x = Dense(128, activation='relu')(x)
    
    # Increased Dropout layer for better regularization
    x = Dropout(0.4)(x)
    
    # Output layer (Class probabilities)
    output_tensor = Dense(num_classes, activation='softmax')(x)
    
    # Build and compile the model
    model = Model(inputs=input_tensor, outputs=output_tensor)
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=CategoricalCrossentropy(label_smoothing=0.1),
                  metrics=['accuracy'])
    return model

# Define the model
input_shape = (40, 24, 1)
num_classes = 8
model = adaptive_attention_pyramid_net(input_shape=input_shape, num_classes=num_classes)

# Model summary
model.summary()

# Define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5, verbose=1)

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val),
                    shuffle=True, callbacks=[lr_scheduler])

# Predictions on the test set
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Evaluate model performance on the test set
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")

# Classification Report
print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix", fontsize=16)
plt.ylabel("True Class", fontsize=14)
plt.xlabel("Predicted Class", fontsize=14)
plt.show()

# ROC Curve and AUC
fpr = {}
tpr = {}
roc_auc = {}
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate", fontsize=14)
plt.ylabel("True Positive Rate", fontsize=14)
plt.title("ROC Curve for Each Class", fontsize=16)
plt.legend(loc="lower right")
plt.show()

# Plot training history (accuracy and loss graphs)
def plot_training_history(history):
    # Retrieve accuracy and loss values from training history
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    epochs = range(1, len(acc) + 1)
    
    # Plot training & validation accuracy values
    plt.figure()
    plt.plot(epochs, acc, label='Training Accuracy', color='#2E8B57', linewidth=2)  # Green
    plt.plot(epochs, val_acc, label='Validation Accuracy', color='#1E90FF', linewidth=2)  # Blue
    plt.title('Training and Validation Accuracy', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Accuracy', fontweight='bold', fontsize=14)
    plt.legend(loc='lower right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the accuracy plot to the output folder
    acc_plot_path = os.path.join('/kaggle/working/', 'accuracy_plot.png')
    plt.savefig(acc_plot_path, dpi=300)
    plt.show()

    # Plot training & validation loss values
    plt.figure()
    plt.plot(epochs, loss, label='Training Loss', color='#FF6347', linewidth=2)  # Tomato red
    plt.plot(epochs, val_loss, label='Validation Loss', color='#8A2BE2', linewidth=2)  # BlueViolet
    plt.title('Training and Validation Loss', fontweight='bold', fontsize=16)
    plt.xlabel('Epochs', fontweight='bold', fontsize=14)
    plt.ylabel('Loss', fontweight='bold', fontsize=14)
    plt.legend(loc='upper right')
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.tight_layout()
    
    # Save the loss plot to the output folder
    loss_plot_path = os.path.join('/kaggle/working/', 'loss_plot.png')
    plt.savefig(loss_plot_path, dpi=300)
    plt.show()

# Plot training history
plot_training_history(history)
# Out:
# Shape of y_train: (23094, 8)
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 40, 24, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 40, 24,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 40, 24,    │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 40, 24,    │        320 │ batch_normalizat… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 40, 24,    │      2,112 │ depthwise_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 40, 24,    │     36,928 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ conv2d_2[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 8)         │        520 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │        576 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 40, 24,    │          0 │ conv2d_2[0][0],   │
# │                     │ 64)               │            │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 40, 24,    │        256 │ multiply[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 20, 12,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 20, 12,    │        640 │ max_pooling2d[0]… │
# │ (DepthwiseConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 20, 12,    │      8,320 │ depthwise_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 20, 12,    │    147,584 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ conv2d_4[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 128)       │      2,176 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 20, 12,    │          0 │ conv2d_4[0][0],   │
# │ (Multiply)          │ 128)              │            │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 20, 12,    │        512 │ multiply_1[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 10, 6,     │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 10, 6,     │      1,280 │ max_pooling2d_1[… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 10, 6,     │     33,024 │ depthwise_conv2d… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 10, 6,     │    590,080 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ conv2d_6[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 10, 6,     │          0 │ conv2d_6[0][0],   │
# │ (Multiply)          │ 256)              │            │ dense_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 10, 6,     │      1,024 │ multiply_2[0][0]  │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 5, 3, 256) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ max_pooling2d_2[… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     32,896 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 128)       │          0 │ dense_6[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 8)         │      1,032 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 880,256 (3.36 MB)
#  Trainable params: 878,400 (3.35 MB)
#  Non-trainable params: 1,856 (7.25 KB)
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730279765.764100      94 service.cc:145] XLA service 0x7af2e402a640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1730279765.764149      94 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#  18/722 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.1808 - loss: 2.7178
# I0000 00:00:1730279774.126001      94 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 30s 20ms/step - accuracy: 0.4376 - loss: 1.6939 - val_accuracy: 0.6224 - val_loss: 1.2348 - learning_rate: 0.0010
# Epoch 2/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7045 - loss: 1.1325 - val_accuracy: 0.7315 - val_loss: 1.0557 - learning_rate: 0.0010
# Epoch 3/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7657 - loss: 1.0003 - val_accuracy: 0.7846 - val_loss: 0.9312 - learning_rate: 0.0010
# Epoch 4/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.7986 - loss: 0.9320 - val_accuracy: 0.7806 - val_loss: 0.9633 - learning_rate: 0.0010
# Epoch 5/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8349 - loss: 0.8556 - val_accuracy: 0.7760 - val_loss: 0.9384 - learning_rate: 0.0010
# Epoch 6/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8516 - loss: 0.8240 - val_accuracy: 0.8043 - val_loss: 0.8719 - learning_rate: 0.0010
# Epoch 7/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8754 - loss: 0.7731 - val_accuracy: 0.7737 - val_loss: 0.9946 - learning_rate: 0.0010
# Epoch 8/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8966 - loss: 0.7288 - val_accuracy: 0.8533 - val_loss: 0.8046 - learning_rate: 0.0010
# Epoch 9/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9156 - loss: 0.6914 - val_accuracy: 0.8268 - val_loss: 0.8623 - learning_rate: 0.0010
# Epoch 10/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9335 - loss: 0.6553 - val_accuracy: 0.8499 - val_loss: 0.8329 - learning_rate: 0.0010
# Epoch 11/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9491 - loss: 0.6251 - val_accuracy: 0.8545 - val_loss: 0.8069 - learning_rate: 0.0010
# Epoch 12/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9556 - loss: 0.6079 - val_accuracy: 0.8712 - val_loss: 0.7934 - learning_rate: 0.0010
# Epoch 13/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9626 - loss: 0.5945 - val_accuracy: 0.7968 - val_loss: 0.9645 - learning_rate: 0.0010
# Epoch 14/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9692 - loss: 0.5805 - val_accuracy: 0.8083 - val_loss: 0.9690 - learning_rate: 0.0010
# Epoch 15/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9750 - loss: 0.5668 - val_accuracy: 0.8620 - val_loss: 0.8160 - learning_rate: 0.0010
# Epoch 16/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9780 - loss: 0.5584 - val_accuracy: 0.8805 - val_loss: 0.7823 - learning_rate: 0.0010
# Epoch 17/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9776 - loss: 0.5562 - val_accuracy: 0.8100 - val_loss: 0.9072 - learning_rate: 0.0010
# Epoch 18/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9819 - loss: 0.5466 - val_accuracy: 0.8666 - val_loss: 0.8168 - learning_rate: 0.0010
# Epoch 19/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9812 - loss: 0.5465 - val_accuracy: 0.8886 - val_loss: 0.7848 - learning_rate: 0.0010
# Epoch 20/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9853 - loss: 0.5373 - val_accuracy: 0.8430 - val_loss: 0.8510 - learning_rate: 0.0010
# Epoch 21/50
# 716/722 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9827 - loss: 0.5429
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9827 - loss: 0.5429 - val_accuracy: 0.8516 - val_loss: 0.8500 - learning_rate: 0.0010
# Epoch 22/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9913 - loss: 0.5188 - val_accuracy: 0.8984 - val_loss: 0.7249 - learning_rate: 5.0000e-04
# Epoch 23/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9984 - loss: 0.5007 - val_accuracy: 0.8897 - val_loss: 0.7383 - learning_rate: 5.0000e-04
# Epoch 24/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9990 - loss: 0.4972 - val_accuracy: 0.9042 - val_loss: 0.7113 - learning_rate: 5.0000e-04
# Epoch 25/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9983 - loss: 0.4969 - val_accuracy: 0.8978 - val_loss: 0.7410 - learning_rate: 5.0000e-04
# Epoch 26/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9960 - loss: 0.5021 - val_accuracy: 0.8868 - val_loss: 0.7562 - learning_rate: 5.0000e-04
# Epoch 27/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9945 - loss: 0.5062 - val_accuracy: 0.9001 - val_loss: 0.7379 - learning_rate: 5.0000e-04
# Epoch 28/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9962 - loss: 0.5000 - val_accuracy: 0.9030 - val_loss: 0.7273 - learning_rate: 5.0000e-04
# Epoch 29/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9983 - loss: 0.4952 - val_accuracy: 0.9094 - val_loss: 0.7038 - learning_rate: 5.0000e-04
# Epoch 30/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9963 - loss: 0.4996 - val_accuracy: 0.8978 - val_loss: 0.7183 - learning_rate: 5.0000e-04
# Epoch 31/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9967 - loss: 0.4995 - val_accuracy: 0.8926 - val_loss: 0.7727 - learning_rate: 5.0000e-04
# Epoch 32/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9975 - loss: 0.4965 - val_accuracy: 0.9070 - val_loss: 0.7216 - learning_rate: 5.0000e-04
# Epoch 33/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9979 - loss: 0.4951 - val_accuracy: 0.9018 - val_loss: 0.7274 - learning_rate: 5.0000e-04
# Epoch 34/50
# 721/722 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9973 - loss: 0.4963
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9973 - loss: 0.4963 - val_accuracy: 0.8995 - val_loss: 0.7428 - learning_rate: 5.0000e-04
# Epoch 35/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9984 - loss: 0.4929 - val_accuracy: 0.9036 - val_loss: 0.7066 - learning_rate: 2.5000e-04
# Epoch 36/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4880 - val_accuracy: 0.9070 - val_loss: 0.7049 - learning_rate: 2.5000e-04
# Epoch 37/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9997 - loss: 0.4873 - val_accuracy: 0.9030 - val_loss: 0.7112 - learning_rate: 2.5000e-04
# Epoch 38/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9991 - loss: 0.4887 - val_accuracy: 0.9059 - val_loss: 0.7113 - learning_rate: 2.5000e-04
# Epoch 39/50
# 718/722 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9995 - loss: 0.4878
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9995 - loss: 0.4878 - val_accuracy: 0.9024 - val_loss: 0.7252 - learning_rate: 2.5000e-04
# Epoch 40/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9997 - loss: 0.4866 - val_accuracy: 0.9082 - val_loss: 0.6972 - learning_rate: 1.2500e-04
# Epoch 41/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9996 - loss: 0.4861 - val_accuracy: 0.9134 - val_loss: 0.6971 - learning_rate: 1.2500e-04
# Epoch 42/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4855 - val_accuracy: 0.9036 - val_loss: 0.7161 - learning_rate: 1.2500e-04
# Epoch 43/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9999 - loss: 0.4857 - val_accuracy: 0.9111 - val_loss: 0.7051 - learning_rate: 1.2500e-04
# Epoch 44/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4850 - val_accuracy: 0.8961 - val_loss: 0.7308 - learning_rate: 1.2500e-04
# Epoch 45/50
# 721/722 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9998 - loss: 0.4852
# Epoch 45: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4852 - val_accuracy: 0.9088 - val_loss: 0.7082 - learning_rate: 1.2500e-04
# Epoch 46/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4852 - val_accuracy: 0.9082 - val_loss: 0.7097 - learning_rate: 6.2500e-05
# Epoch 47/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.9998 - loss: 0.4845 - val_accuracy: 0.9082 - val_loss: 0.7097 - learning_rate: 6.2500e-05
# Epoch 48/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9998 - loss: 0.4844 - val_accuracy: 0.9099 - val_loss: 0.7023 - learning_rate: 6.2500e-05
# Epoch 49/50
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9996 - loss: 0.4847 - val_accuracy: 0.9128 - val_loss: 0.7013 - learning_rate: 6.2500e-05
# Epoch 50/50
# 721/722 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9999 - loss: 0.4841
# Epoch 50: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 722/722 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9999 - loss: 0.4841 - val_accuracy: 0.9117 - val_loss: 0.7003 - learning_rate: 6.2500e-05
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step
# 127/127 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9051 - loss: 0.7215
# Test Loss: 0.7032777070999146
# Test Accuracy: 0.9119247794151306
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      1102
#            1       0.87      0.84      0.86       701
#            2       0.99      0.99      0.99       812
#            3       0.93      0.96      0.95        90
#            4       0.89      0.83      0.86       144
#            5       0.85      0.83      0.84       146
#            6       0.91      0.92      0.92       455
#            7       0.91      0.92      0.92       592
#
#     accuracy                           0.91      4042
#    macro avg       0.91      0.90      0.90      4042
# weighted avg       0.91      0.91      0.91      4042
